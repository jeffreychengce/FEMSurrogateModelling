# %% [markdown]
# # Jax Implementation of MPM for Axial vibration of 1D bar

# %% [markdown]
# ## Analytical Solution

# %%
import numpy as np

def axial_vibration_bar1d(L, E, rho, duration, dt, v0, x):

    # Frequency of system mode 1
    w1 = np.pi / (2 * L) * np.sqrt(E/rho)
    b1 = np.pi / (2 * L)

    # position and velocity in time
    tt, vt, xt = [], [], []

    nsteps = int(duration/dt)
    t = 0
    for _ in range(nsteps):
        vt.append(v0 * np.cos(w1 * t) * np.sin(b1 * x))
        xt.append(v0 / w1 * np.sin(w1 * t) * np.sin(b1 * x))
        tt.append(t)

        t += dt
    
    return tt, vt, xt

# %%
import matplotlib.pyplot as plt

# Properties
E = 100
L = 25

# analytical solution at the end of the bar
ta, va, xa = axial_vibration_bar1d(L = L, E = E, rho = 1, duration = 100, dt = 0.01, v0 = 0.1, x = 12.5)

plt.plot(ta, va, 'r',linewidth=2,label='analytical')

plt.xlabel('time (s)')
plt.ylabel('velocity (m/s)')
plt.legend()
plt.show()

# %% [markdown]
# ## Jax MPM Implementation

# %%
import jax.numpy as jnp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1818496\3322733769.py in <cell line: 1>()
# ----> 1 import jax.numpy as jnp
#
# ~\AppData\Roaming\Python\Python39\site-packages\jax\__init__.py in <module>
#      19
#      20 # flake8: noqa: F401
# ---> 21 from .config import config
#      22 from .api import (
#      23   ad,  # TODO(phawkins): update users to avoid this.
#
# ~\AppData\Roaming\Python\Python39\site-packages\jax\config.py in <module>
#      17 import threading
#      18 from typing import Optional
# ---> 19 from jax import lib
#      20
#      21 def bool_env(varname: str, default: bool) -> bool:
#
# ~\AppData\Roaming\Python\Python39\site-packages\jax\lib\__init__.py in <module>
#      21 ]
#      22
# ---> 23 import jaxlib
#      24
#      25 # Must be kept in sync with the jaxlib version in build/test-requirements.txt
#
# ModuleNotFoundError: No module named 'jaxlib'
