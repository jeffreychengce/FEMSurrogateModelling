# %%
import jax.numpy as jnp
from jax import grad, jit, vmap, lax
import jax.scipy as jsp
import jax.scipy.optimize as jsp_opt
import optax 
import jaxopt
from jaxopt import ScipyBoundedMinimize
import matplotlib.pyplot as plt
import jax

@jit
def mpm(E):
    # nsteps
    nsteps = 10
    
    # mom tolerance
    tol = 1e-12

    # Domain length
    Lx = 25
    Ly = 25

    # Material properties
    rho = 1

    # Computational grid
    nelementsx = 13
    nelementsy = 13
    nelements = nelementsx * nelementsy
    
    dx = Lx / nelementsx
    dy = Lx / nelementsy
    
    # Create equally spaced nodes
    x_n, y_n = jnp.meshgrid(jnp.linspace(0, Lx, nelementsx + 1), jnp.linspace(0, Ly, nelementsy + 1))
    x_n = x_n.flatten()
    y_n = y_n.flatten()
    nnodes = len(x_n)
    
    
    # Set-up a 2D array of elements with node ids
    elements = jnp.zeros((nelements, 4), dtype=int)
    for nidx in range(nelementsx):
        for nidy in range(nelementsy):
            nid = nidx * nelements + nidy
            elements = elements.at[nid, 0].set(nidx * nelements + nidy)
            elements = elements.at[nid, 1].set(nidx * nelements + nidy + 1)
            elements = elements.at[nid, 2].set((nidx + 1) * nelements + nidy)
            elements = elements.at[nid, 3].set((nidx + 1) * nelements + nidy + 1)
            
    # Loading conditions
    v0x = 0.1              # initial velocity
    v0y = 0.1              # initial velocity
    c  = jnp.sqrt(E/rho)   # speed of sound
    b1 = jnp.pi / (2 * Lx) # beta1
    b2 = jnp.pi / (2 * Ly) # beta2
    w1 = b1 * c            # omega1
    w2 = b2 * c            # omega2
    
    # Create material points at the center of each element
    nparticles = nelements  # number of particles
    
    # Id of the particle in the central element
    pmid = nelements // 2  # Midpoint of the material points
    
    # Material point properties
    x_p       = jnp.zeros(nparticles)            # positions
    y_p       = jnp.zeros(nparticles)            # positions
    vol_p     = jnp.ones(nparticles) * dx * dy   # volume
    mass_p    = vol_p * rho                      # mass
    stress_px = jnp.zeros(nparticles)            # stress
    stress_py = jnp.zeros(nparticles)            # stress
    vel_px    = jnp.zeros(nparticles)            # velocity
    vel_py    = jnp.zeros(nparticles)            # velocity
    
    # Create particle at the center
    x_p      = 0.5 * (x_n[:-1] + x_n[1:])
    y_p      = 0.5 * (y_n[:-1] + y_n[1:])
    # set initial velocities
    vel_px   = v0x * jnp.sin(b1 * x_p)
    vel_py   = v0y * jnp.sin(b2 * y_p)
    
    # Time steps and duration
    dt_crit = jnp.max(jnp.array([dx / c, dy / c]))
    dt = 0.02
    
    # results
    tt = jnp.zeros(nsteps)
    vt = jnp.zeros((nsteps, 2))
    xt = jnp.zeros((nsteps, 2))
    
    def step(i, carry):
        x_p, y_p, mass_p, vel_px, vel_py, vol_p, stress_px, stress_py, vt, xt = carry
        # reset nodal values
        mass_n  = jnp.zeros(nnodes)   # mass
        mom_nx   = jnp.zeros(nnodes)  # momentum
        mom_ny   = jnp.zeros(nnodes)  # momentum
        fint_nx  = jnp.zeros(nnodes)  # internal force
        fint_ny  = jnp.zeros(nnodes)  # internal force

        # iterate through each element
        for eid in range(nelements):
            # get nodal ids
            nid1, nid2, nid3, nid4 = elements[eid]

            # compute shape functions and derivatives
            N1x = 1 - abs(x_p[eid] - x_n[nid1]) / dx
            N2x = 1 - abs(x_p[eid] - x_n[nid2]) / dx
            N3x = 1 - abs(x_p[eid] - x_n[nid3]) / dx
            N4x = 1 - abs(x_p[eid] - x_n[nid4]) / dx
            N1y = 1 - abs(y_p[eid] - y_n[nid1]) / dy
            N2y = 1 - abs(y_p[eid] - y_n[nid2]) / dy
            N3y = 1 - abs(y_p[eid] - y_n[nid3]) / dy
            N4y = 1 - abs(y_p[eid] - y_n[nid4]) / dy
            
            dN1x = -1/dx
            dN2x = 1/dx
            dN3x = -1/dx
            dN4x = 1/dx
            dN1y = -1/dy
            dN2y = 1/dy
            dN3y = -1/dy
            dN4y = 1/dy

            # map particle mass and momentum to nodes
            mass_n = mass_n.at[nid1].set(mass_n[nid1] + N1x * mass_p[eid])
            mass_n = mass_n.at[nid2].set(mass_n[nid2] + N2x * mass_p[eid])
            mass_n = mass_n.at[nid3].set(mass_n[nid3] + N3x * mass_p[eid])
            mass_n = mass_n.at[nid4].set(mass_n[nid4] + N4x * mass_p[eid])

            mom_nx = mom_nx.at[nid1].set(mom_nx[nid1] + N1x * mass_p[eid] * vel_px[eid])
            mom_nx = mom_nx.at[nid2].set(mom_nx[nid2] + N2x * mass_p[eid] * vel_px[eid])
            mom_nx = mom_nx.at[nid3].set(mom_nx[nid3] + N3x * mass_p[eid] * vel_px[eid])
            mom_nx = mom_nx.at[nid4].set(mom_nx[nid4] + N4x * mass_p[eid] * vel_px[eid])
            mom_ny = mom_ny.at[nid1].set(mom_ny[nid1] + N1y * mass_p[eid] * vel_py[eid])
            mom_ny = mom_ny.at[nid2].set(mom_ny[nid2] + N2y * mass_p[eid] * vel_py[eid])
            mom_ny = mom_ny.at[nid3].set(mom_ny[nid3] + N3y * mass_p[eid] * vel_py[eid])
            mom_ny = mom_ny.at[nid4].set(mom_ny[nid4] + N4y * mass_p[eid] * vel_py[eid])

            # compute nodal internal force
            fint_nx = fint_nx.at[nid1].set(fint_nx[nid1] - vol_p[eid] * stress_px[eid] * dN1x)
            fint_nx = fint_nx.at[nid2].set(fint_nx[nid2] - vol_p[eid] * stress_px[eid] * dN2x)
            fint_nx = fint_nx.at[nid3].set(fint_nx[nid3] - vol_p[eid] * stress_px[eid] * dN3x)
            fint_nx = fint_nx.at[nid4].set(fint_nx[nid4] - vol_p[eid] * stress_px[eid] * dN4x)
            fint_ny = fint_ny.at[nid1].set(fint_ny[nid1] - vol_p[eid] * stress_py[eid] * dN1y)
            fint_ny = fint_ny.at[nid2].set(fint_ny[nid2] - vol_p[eid] * stress_py[eid] * dN2y)
            fint_ny = fint_ny.at[nid3].set(fint_ny[nid3] - vol_p[eid] * stress_py[eid] * dN3y)
            fint_ny = fint_ny.at[nid4].set(fint_ny[nid4] - vol_p[eid] * stress_py[eid] * dN4y)
        
        # apply boundary conditions
        mom_nx = mom_nx.at[::nelementsx+1].set(jnp.zeros(nelementsy+1))  # Nodal velocity v = 0 in m * v at node 0.
        mom_ny = mom_ny.at[::nelementsy+1].set(jnp.zeros(nelementsx+1))  # Nodal velocity v = 0 in m * v at node 0.
        fint_nx = fint_nx.at[::nelementsx+1].set(jnp.zeros(nelementsy+1))  # Nodal force f = m * a, where a = 0 at node 0.
        fint_ny = fint_ny.at[::nelementsy+1].set(jnp.zeros(nelementsx+1))  # Nodal force f = m * a, where a = 0 at node 0.

        # update nodal momentum
        mom_nx = mom_nx + fint_nx * dt
        mom_ny = mom_ny + fint_ny * dt

        # update particle velocity position and stress
        # iterate through each element
        for eid in range(nelements):
            # get nodal ids
            nid1, nid2, nid3, nid4 = elements[eid]

            # compute shape functions and derivatives
            N1x = 1 - abs(x_p[eid] - x_n[nid1]) / dx
            N2x = 1 - abs(x_p[eid] - x_n[nid2]) / dx
            N3x = 1 - abs(x_p[eid] - x_n[nid3]) / dx
            N4x = 1 - abs(x_p[eid] - x_n[nid4]) / dx
            N1y = 1 - abs(y_p[eid] - y_n[nid1]) / dy
            N2y = 1 - abs(y_p[eid] - y_n[nid2]) / dy
            N3y = 1 - abs(y_p[eid] - y_n[nid3]) / dy
            N4y = 1 - abs(y_p[eid] - y_n[nid4]) / dy
            
            dN1x = -1/dx
            dN2x = 1/dx
            dN3x = -1/dx
            dN4x = 1/dx
            dN1y = -1/dy
            dN2y = 1/dy
            dN3y = -1/dy
            dN4y = 1/dy
            
            # compute particle velocity
            vel_px = vel_px.at[eid].set(vel_px[eid] + dt * N1x * fint_nx[nid1] / mass_n[nid1])
            vel_px = vel_px.at[eid].set(vel_px[eid] + dt * N2x * fint_nx[nid2] / mass_n[nid2])
            vel_px = vel_px.at[eid].set(vel_px[eid] + dt * N3x * fint_nx[nid3] / mass_n[nid3])
            vel_px = vel_px.at[eid].set(vel_px[eid] + dt * N4x * fint_nx[nid4] / mass_n[nid4])
            vel_py = vel_py.at[eid].set(vel_py[eid] + dt * N1y * fint_ny[nid1] / mass_n[nid1])
            vel_py = vel_py.at[eid].set(vel_py[eid] + dt * N2y * fint_ny[nid2] / mass_n[nid2])
            vel_py = vel_py.at[eid].set(vel_py[eid] + dt * N3y * fint_ny[nid3] / mass_n[nid3])
            vel_py = vel_py.at[eid].set(vel_py[eid] + dt * N4y * fint_ny[nid4] / mass_n[nid4])
            
            
            
            # update particle position based on nodal momentum
            x_p = x_p.at[eid].set(x_p[eid] + dt * (N1x * mom_nx[nid1]/mass_n[nid1] + N2x * mom_nx[nid2]/mass_n[nid2] + N3x * mom_nx[nid3]/mass_n[nid3] + N4x * mom_nx[nid4]/mass_n[nid4]))
            y_p = y_p.at[eid].set(y_p[eid] + dt * (N1y * mom_ny[nid1]/mass_n[nid1] + N2y * mom_ny[nid2]/mass_n[nid2] + N3y * mom_ny[nid3]/mass_n[nid3] + N4y * mom_ny[nid4]/mass_n[nid4]))

            # nodal velocity
            nv1x = mom_nx[nid1]/mass_n[nid1]
            nv2x = mom_nx[nid2]/mass_n[nid2]
            nv3x = mom_nx[nid3]/mass_n[nid3]
            nv4x = mom_nx[nid4]/mass_n[nid4]
            nv1y = mom_ny[nid1]/mass_n[nid1]
            nv2y = mom_ny[nid2]/mass_n[nid2]
            nv3y = mom_ny[nid3]/mass_n[nid3]
            nv4y = mom_ny[nid4]/mass_n[nid4]

             # rate of strain increment
            grad_vx = dN1x * nv1x + dN2x * nv2x + dN3x * nv3x + dN4x * nv4x
            grad_vy = dN1y * nv1y + dN2y * nv2y + dN3y * nv3y + dN4y * nv4y
            # particle dstrain
            dstrainx = grad_vx * dt
            dstrainy = grad_vy * dt
            # particle volume
            vol_p = vol_p.at[eid].set((1 + dstrainx) * (1 + dstrainy) * vol_p[eid])
            # update stress using linear elastic model
            stress_px = stress_px.at[eid].set(stress_px[eid] + E * dstrainx)
            stress_py = stress_py.at[eid].set(stress_py[eid] + E * dstrainy)

        # results
        vt = vt.at[i, 0].set(vel_px[pmid])
        vt = vt.at[i, 1].set(vel_py[pmid])
        xt = xt.at[i, 0].set(x_p[pmid])
        xt = xt.at[i, 1].set(y_p[pmid])

        return (x_p, y_p, mass_p, vel_px, vel_py, vol_p, stress_px, stress_py, vt, xt)

    x_p, y_p, mass_p, vel_px, vel_py, vol_p, stress_px, stress_py, vt, xt = lax.fori_loop(0, nsteps, step, (x_p, y_p, mass_p, vel_px, vel_py, vol_p, stress_px, stress_py, vt, xt))


    
    return vt

# %%
# Assign target
Etarget = 100
target = mpm(Etarget)

print(target)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# [[0.00603785 0.06631228]]

# %%
target[1,:]
# Out:
# Array([0.00603785, 0.06631228], dtype=float32)

# %%
#############################################################
#  NOTE: Uncomment the line only for TFP optimizer and 
#        jaxopt value_and_grad = True
#############################################################
# @jax.value_and_grad
@jit
def compute_loss(E):
    vt = mpm(E)
    return jnp.linalg.norm(vt - target)

# BFGS Optimizer
# TODO: Implement box constrained optimizer
def jaxopt_bfgs(params, niter):
  opt= jaxopt.BFGS(fun=compute_loss, value_and_grad=True, tol=1e-5, implicit_diff=False, maxiter=niter)
  res = opt.run(init_params=params)
  result, _ = res
  return result

# Optimizers
def optax_adam(params, niter):
  # Initialize parameters of the model + optimizer.
  start_learning_rate = 1e-1
  optimizer = optax.adam(start_learning_rate)
  opt_state = optimizer.init(params)

  # A simple update loop.
  for _ in range(niter):
    grads = grad(compute_loss)(params)
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
  return params
  
# Tensor Flow Probability Optimization library
def tfp_lbfgs(params):
  results = tfp.optimizer.lbfgs_minimize(
        jax.jit(compute_loss), initial_position=params, tolerance=1e-5)
  return results.position

# Initial model - Young's modulus 
params = 95.0

# vt = tfp_lbfgs(params)               # LBFGS optimizer
result = optax_adam(params, 1000)     # ADAM optimizer

"""
f = jax.jit(compute_loss)
df = jax.jit(jax.grad(compute_loss))
E = 95.0
print(0, E)
for i in range(10):
    E = E - f(E)/df(E)
    print(i, E)
"""
print("E: {}".format(result))
vel = mpm(result)
# update time steps
dt = 0.02
nsteps = 10
tt = jnp.arange(0, nsteps) * dt


vel = vel.reshape((2,10))
target = target.reshape((2,10))


# Plot results
plt.plot(tt, vel[0,:], 'r', markersize=1, label='mpm')
plt.plot(tt, target[0,:], 'ob', markersize=1, label='mpm-target')
plt.xlabel('time (s)')
plt.ylabel('x velocity (m/s)')
plt.legend()
plt.show()

plt.plot(tt, vel[1,:], 'r', markersize=1, label='mpm')
plt.plot(tt, target[1,:], 'ob', markersize=1, label='mpm-target')
plt.xlabel('time (s)')
plt.ylabel('y velocity (m/s)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 43
#      40 params = 95.0
#      42 # vt = tfp_lbfgs(params)               # LBFGS optimizer
# ---> 43 result = optax_adam(params, 1000)     # ADAM optimizer
#      45 """
#      46 f = jax.jit(compute_loss)
#      47 df = jax.jit(jax.grad(compute_loss))
#    (...)
#      52     print(i, E)
#      53 """
#      54 print("E: {}".format(result))
#
# Cell In[3], line 28, in optax_adam(params, niter)
#      26 # A simple update loop.
#      27 for _ in range(niter):
# ---> 28   grads = grad(compute_loss)(params)
#      29   updates, opt_state = optimizer.update(grads, opt_state)
#      30   params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:1176, in grad.<locals>.grad_f(*args, **kwargs)
#    1173 @wraps(fun, docstr=docstr, argnums=argnums)
#    1174 @api_boundary
#    1175 def grad_f(*args, **kwargs):
# -> 1176   _, g = value_and_grad_f(*args, **kwargs)
#    1177   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:1252, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#    1250   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#    1251 if not has_aux:
# -> 1252   ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#    1253 else:
#    1254   ans, vjp_py, aux = _vjp(
#    1255       f_partial, *dyn_args, has_aux=True, reduce_axes=reduce_axes)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:2794, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2792 if not has_aux:
#    2793   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2794   out_primal, out_vjp = ad.vjp(
#    2795       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2796   out_tree = out_tree()
#    2797 else:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:137, in vjp(traceable, primals, has_aux, reduce_axes)
#     135 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     136   if not has_aux:
# --> 137     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     138   else:
#     139     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:126, in linearize(traceable, *primals, **kwargs)
#     124 _, in_tree = tree_flatten(((primals, primals), {}))
#     125 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 126 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     127 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     128 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:770, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     768 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     769   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 770   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     771   assert not env
#     772   del main, fun, env
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:165, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     162 gen = gen_static_args = out_store = None
#     164 try:
# --> 165   ans = self.f(*args, **dict(self.params, **kwargs))
#     166 except:
#     167   # Some transformations yield from inside context managers, so we have to
#     168   # interrupt them before reraising the exception. Otherwise they will only
#     169   # get garbage-collected at some later time, running their cleanup tasks
#     170   # only after this exception is handled, which can corrupt the global
#     171   # state.
#     172   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:237, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     235 @api_boundary
#     236 def cache_miss(*args, **kwargs):
# --> 237   outs, out_flat, out_tree, args_flat = _python_pjit_helper(
#     238       fun, infer_params_fn, *args, **kwargs)
#     240   executable = _read_most_recent_pjit_call_executable()
#     242   use_fastpath = (
#     243       executable is not None and
#     244       isinstance(executable, pxla.MeshExecutable) and
#    (...)
#     250       all(isinstance(x, xc.ArrayImpl) for x in out_flat)
#     251   )
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:180, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     179 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
# --> 180   args_flat, _, params, in_tree, out_tree, _ = infer_params_fn(
#     181       *args, **kwargs)
#     182   for arg in args_flat:
#     183     dispatch.check_arg(arg)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:443, in jit.<locals>.infer_params(*args, **kwargs)
#     436 def infer_params(*args, **kwargs):
#     437   pjit_info_args = pjit.PjitInfo(
#     438       fun=fun, in_shardings=in_shardings,
#     439       out_shardings=out_shardings, static_argnums=static_argnums,
#     440       static_argnames=static_argnames, donate_argnums=donate_argnums,
#     441       device=device, backend=backend, keep_unused=keep_unused,
#     442       inline=inline, resource_env=None)
# --> 443   return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:520, in common_infer_params(***failed resolving arguments***)
#     511 out_positional_semantics = (
#     512     pxla._PositionalSemantics.GLOBAL
#     513     if jax.config.jax_parallel_functions_output_gda or jax.config.jax_array else
#     514     pxla.positional_semantics.val)
#     516 global_in_avals, canonicalized_in_shardings_flat = _process_in_axis_resources(
#     517     hashable_pytree(in_shardings), local_in_avals, in_tree, in_positional_semantics,
#     518     tuple(isinstance(a, GDA) for a in args_flat), resource_env)
# --> 520 jaxpr, consts, canonicalized_out_shardings_flat = _pjit_jaxpr(
#     521     flat_fun, hashable_pytree(out_shardings), global_in_avals,
#     522     HashableFunction(out_tree, closure=()),
#     523     ('jit' if resource_env is None else 'pjit'))
#     525 if (any(_is_from_gda(i) for i in canonicalized_in_shardings_flat) or
#     526     not jax.config.jax_array):
#     527   canonicalized_in_shardings_flat = _maybe_replace_from_gda_with_pspec(
#     528       canonicalized_in_shardings_flat, args_flat)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:301, in cache.<locals>.memoized_fun(fun, *args)
#     299   fun.populate_stores(stores)
#     300 else:
# --> 301   ans = call(fun, *args)
#     302   cache[key] = (ans, fun.stores)
#     304 return ans
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:932, in _pjit_jaxpr(fun, out_shardings_thunk, global_in_avals, out_tree, api_name)
#     928   pxla.positional_semantics.val = pxla._PositionalSemantics.GLOBAL
#     929   with dispatch.log_elapsed_time(f"Finished tracing + transforming {fun.__name__} "
#     930                                  "for pjit in {elapsed_time} sec",
#     931                                   event=dispatch.JAXPR_TRACE_EVENT):
# --> 932     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(
#     933         fun, global_in_avals, debug_info=pe.debug_info_final(fun, api_name))
#     934 finally:
#     935   pxla.positional_semantics.val = prev_positional_val
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1985, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    1983 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    1984   main.jaxpr_stack = ()  # type: ignore
# -> 1985   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    1986     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    1987   del main, fun
#    1988 return jaxpr, out_avals, consts
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:2002, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2000 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2001 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2002 ans = fun.call_wrapped(*in_tracers_)
#    2003 out_tracers = map(trace.full_raise, ans)
#    2004 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:165, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     162 gen = gen_static_args = out_store = None
#     164 try:
# --> 165   ans = self.f(*args, **dict(self.params, **kwargs))
#     166 except:
#     167   # Some transformations yield from inside context managers, so we have to
#     168   # interrupt them before reraising the exception. Otherwise they will only
#     169   # get garbage-collected at some later time, running their cleanup tasks
#     170   # only after this exception is handled, which can corrupt the global
#     171   # state.
#     172   while stack:
#
# Cell In[3], line 8, in compute_loss(E)
#       6 @jit
#       7 def compute_loss(E):
# ----> 8     vt = mpm(E)
#       9     return jnp.linalg.norm(vt - target)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:237, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     235 @api_boundary
#     236 def cache_miss(*args, **kwargs):
# --> 237   outs, out_flat, out_tree, args_flat = _python_pjit_helper(
#     238       fun, infer_params_fn, *args, **kwargs)
#     240   executable = _read_most_recent_pjit_call_executable()
#     242   use_fastpath = (
#     243       executable is not None and
#     244       isinstance(executable, pxla.MeshExecutable) and
#    (...)
#     250       all(isinstance(x, xc.ArrayImpl) for x in out_flat)
#     251   )
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:180, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     179 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
# --> 180   args_flat, _, params, in_tree, out_tree, _ = infer_params_fn(
#     181       *args, **kwargs)
#     182   for arg in args_flat:
#     183     dispatch.check_arg(arg)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:443, in jit.<locals>.infer_params(*args, **kwargs)
#     436 def infer_params(*args, **kwargs):
#     437   pjit_info_args = pjit.PjitInfo(
#     438       fun=fun, in_shardings=in_shardings,
#     439       out_shardings=out_shardings, static_argnums=static_argnums,
#     440       static_argnames=static_argnames, donate_argnums=donate_argnums,
#     441       device=device, backend=backend, keep_unused=keep_unused,
#     442       inline=inline, resource_env=None)
# --> 443   return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:520, in common_infer_params(***failed resolving arguments***)
#     511 out_positional_semantics = (
#     512     pxla._PositionalSemantics.GLOBAL
#     513     if jax.config.jax_parallel_functions_output_gda or jax.config.jax_array else
#     514     pxla.positional_semantics.val)
#     516 global_in_avals, canonicalized_in_shardings_flat = _process_in_axis_resources(
#     517     hashable_pytree(in_shardings), local_in_avals, in_tree, in_positional_semantics,
#     518     tuple(isinstance(a, GDA) for a in args_flat), resource_env)
# --> 520 jaxpr, consts, canonicalized_out_shardings_flat = _pjit_jaxpr(
#     521     flat_fun, hashable_pytree(out_shardings), global_in_avals,
#     522     HashableFunction(out_tree, closure=()),
#     523     ('jit' if resource_env is None else 'pjit'))
#     525 if (any(_is_from_gda(i) for i in canonicalized_in_shardings_flat) or
#     526     not jax.config.jax_array):
#     527   canonicalized_in_shardings_flat = _maybe_replace_from_gda_with_pspec(
#     528       canonicalized_in_shardings_flat, args_flat)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:301, in cache.<locals>.memoized_fun(fun, *args)
#     299   fun.populate_stores(stores)
#     300 else:
# --> 301   ans = call(fun, *args)
#     302   cache[key] = (ans, fun.stores)
#     304 return ans
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:932, in _pjit_jaxpr(fun, out_shardings_thunk, global_in_avals, out_tree, api_name)
#     928   pxla.positional_semantics.val = pxla._PositionalSemantics.GLOBAL
#     929   with dispatch.log_elapsed_time(f"Finished tracing + transforming {fun.__name__} "
#     930                                  "for pjit in {elapsed_time} sec",
#     931                                   event=dispatch.JAXPR_TRACE_EVENT):
# --> 932     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(
#     933         fun, global_in_avals, debug_info=pe.debug_info_final(fun, api_name))
#     934 finally:
#     935   pxla.positional_semantics.val = prev_positional_val
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1985, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    1983 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    1984   main.jaxpr_stack = ()  # type: ignore
# -> 1985   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    1986     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    1987   del main, fun
#    1988 return jaxpr, out_avals, consts
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:2002, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2000 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2001 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2002 ans = fun.call_wrapped(*in_tracers_)
#    2003 out_tracers = map(trace.full_raise, ans)
#    2004 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:165, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     162 gen = gen_static_args = out_store = None
#     164 try:
# --> 165   ans = self.f(*args, **dict(self.params, **kwargs))
#     166 except:
#     167   # Some transformations yield from inside context managers, so we have to
#     168   # interrupt them before reraising the exception. Otherwise they will only
#     169   # get garbage-collected at some later time, running their cleanup tasks
#     170   # only after this exception is handled, which can corrupt the global
#     171   # state.
#     172   while stack:
#
# Cell In[1], line 150, in mpm(E)
#     146     xt = xt.at[i].set(x_p[pmid])
#     148     return (x_p, mass_p, vel_p, vol_p, stress_p, vt, xt)
# --> 150 x_p, mass_p, vel_p, vol_p, stress_p, vt, xt = lax.fori_loop(0, nsteps, step, (x_p, mass_p, vel_p, vol_p, stress_p, vt, xt))
#     153 return vt
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1682, in fori_loop(lower, upper, body_fun, init_val)
#    1678   if config.jax_disable_jit and upper_ == lower_:
#    1679     # non-jit implementation of scan does not support length=0
#    1680     return init_val
# -> 1682   (_, result), _ = scan(_fori_scan_body_fun(body_fun), (lower_, init_val),
#    1683                         None, length=upper_ - lower_)
#    1684 else:
#    1685   _, _, result = while_loop(_fori_cond_fun, _fori_body_fun(body_fun),
#    1686                             (lower, upper, init_val))
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:258, in scan(f, init, xs, length, reverse, unroll)
#     251   return init_flat, carry_avals, carry_avals_out, init_tree, in_flat, jaxpr, consts, out_tree, out_tree_children
#     253 # The carry input and output avals must match exactly. However, we want to account for
#     254 # the case when init contains weakly-typed values (e.g. Python scalars), with avals that
#     255 # may not match the output despite being compatible by virtue of their weak type.
#     256 # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#     257 # necessary, a second time with modified init values.
# --> 258 init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#     259 new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#     260 if changed:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:244, in scan.<locals>._create_jaxpr(init)
#     241 in_flat, in_tree = tree_flatten((init, xs))
#     243 carry_avals = tuple(_map(_abstractify, init_flat))
# --> 244 jaxpr, consts, out_tree = _initial_style_jaxpr(
#     245     f, in_tree, (*carry_avals, *x_avals), "scan")
#     246 out_tree_children = out_tree.children()
#     247 if len(out_tree_children) != 2:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/common.py:60, in _initial_style_jaxpr(fun, in_tree, in_avals, primitive_name)
#      57 @weakref_lru_cache
#      58 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals,
#      59                          primitive_name: Optional[str] = None):
# ---> 60   jaxpr, consts, out_tree = _initial_style_open_jaxpr(
#      61       fun, in_tree, in_avals, primitive_name)
#      62   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#      63   return closed_jaxpr, consts, out_tree
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/common.py:54, in _initial_style_open_jaxpr(fun, in_tree, in_avals, primitive_name)
#      52 wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
#      53 debug = pe.debug_info(fun, in_tree, False, primitive_name or "<unknown>")
# ---> 54 jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals, debug)
#      55 return jaxpr, consts, out_tree()
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1985, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    1983 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    1984   main.jaxpr_stack = ()  # type: ignore
# -> 1985   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    1986     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    1987   del main, fun
#    1988 return jaxpr, out_avals, consts
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:2002, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2000 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2001 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2002 ans = fun.call_wrapped(*in_tracers_)
#    2003 out_tracers = map(trace.full_raise, ans)
#    2004 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:165, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     162 gen = gen_static_args = out_store = None
#     164 try:
# --> 165   ans = self.f(*args, **dict(self.params, **kwargs))
#     166 except:
#     167   # Some transformations yield from inside context managers, so we have to
#     168   # interrupt them before reraising the exception. Otherwise they will only
#     169   # get garbage-collected at some later time, running their cleanup tasks
#     170   # only after this exception is handled, which can corrupt the global
#     171   # state.
#     172   while stack:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1598, in _fori_scan_body_fun.<locals>.scanned_fun(loop_carry, _)
#    1596 def scanned_fun(loop_carry, _):
#    1597   i, x = loop_carry
# -> 1598   return (i + 1, body_fun()(i, x)), None
#
# Cell In[1], line 140, in mpm.<locals>.step(i, carry)
#     138 dstrain = grad_v * dt
#     139 # particle volume
# --> 140 vol_p = vol_p.at[eid].set((1 + dstrain) * vol_p[eid])
#     141 # update stress using linear elastic model
#     142 stress_p = stress_p.at[eid].set(stress_p[eid] + E * dstrain)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:648, in Tracer.__getitem__(self, idx)
# --> 648 def __getitem__(self, idx): return self.aval._getitem(self, idx)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:3921, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    3916 if (arr.ndim > 0 and isinstance(idx, (int, np.integer)) and
#    3917     not isinstance(idx, (bool, np.bool_)) and isinstance(arr.shape[0], int)):
#    3918   if 0 <= idx < arr.shape[0]:
#    3919     # Use dynamic rather than static index here to avoid slow repeated execution:
#    3920     # See https://github.com/google/jax/issues/12198
# -> 3921     return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
#    3922 if (arr.ndim > 0 and isinstance(arr.shape[0], int) and
#    3923     isinstance(idx, slice) and
#    3924     (type(idx.start) is int or idx.start is None) and
#    3925     (type(idx.stop)  is int or idx.stop is  None) and
#    3926     (type(idx.step)  is int or idx.step is  None)):
#    3927   n = arr.shape[0]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/slicing.py:701, in dynamic_index_in_dim(operand, index, axis, keepdims)
#     699   return result
#     700 else:
# --> 701   return lax.squeeze(result, (axis,))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/lax.py:1328, in squeeze(array, dimensions)
#    1326 def squeeze(array: ArrayLike, dimensions: Sequence[int]) -> Array:
#    1327   """Squeeze any number of size 1 dimensions from an array."""
# -> 1328   ndim = np.ndim(array)
#    1329   dimensions = tuple(sorted(canonicalize_axis(i, ndim) for i in dimensions))
#    1330   if not dimensions and isinstance(array, Array):
#
# KeyboardInterrupt:

# %%
result
# Out:
# Array(100.002594, dtype=float32)
